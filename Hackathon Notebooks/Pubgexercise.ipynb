# %%
import pandas as pd
import numpy as np
import matplotlib as plot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pubg = pd.read_csv("C:\\Users\\aswin\\Downloads\\train_V2.csv\\train_V2.csv",nrows=50000)

# %% [markdown]
# #### I took only 50000 rows since the dataset had many rows and my system was not at all processing.

# %%
pubg.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 0         0.00      0              0      0         60  ...        0
# 1        91.47      0              0      0         57  ...        0
# 2        68.00      0              0      0         47  ...        0
# 3        32.90      0              0      0         75  ...        0
# 4       100.00      0              0      0         45  ...        0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0        0.0000          0          0.00          0               0
# ...

# %%
pubg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               50000 non-null  object
#  1   groupId          50000 non-null  object
#  2   matchId          50000 non-null  object
#  3   assists          50000 non-null  int64
#  4   boosts           50000 non-null  int64
#  5   damageDealt      50000 non-null  float64
#  6   DBNOs            50000 non-null  int64
#  7   headshotKills    50000 non-null  int64
#  8   heals            50000 non-null  int64
#  9   killPlace        50000 non-null  int64
#  10  killPoints       50000 non-null  int64
#  11  kills            50000 non-null  int64
#  12  killStreaks      50000 non-null  int64
#  13  longestKill      50000 non-null  float64
#  14  matchDuration    50000 non-null  int64
#  15  matchType        50000 non-null  object
#  16  maxPlace         50000 non-null  int64
# ...

# %%
pubg.plot(kind = 'scatter', x = 'walkDistance', y = 'weaponsAcquired')
#Most of the players have walked a distance of 0-6000 metres and acquired atleast 10 weapons
# Out:
# <AxesSubplot:xlabel='walkDistance', ylabel='weaponsAcquired'>

# %%
pubg.plot(kind = 'scatter', x = 'killPlace', y = 'kills')
## Players who are at KillPlace 0-20 have the most number of kills.
# Out:
# <AxesSubplot:xlabel='killPlace', ylabel='kills'>

# %%
sns.distplot(pubg['kills'])
#Most of the players kills range between 0 to 5
# Out:
# C:\Users\aswin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='kills', ylabel='Density'>

# %%
sns.boxplot(x = "kills",y='headshotKills',data = pubg)
# Players who have the highest kills also have high headshot kill counts
# Out:
# <AxesSubplot:xlabel='kills', ylabel='headshotKills'>

# %%
sns.distplot(pubg['revives'])
# Most of the players dont revive their team mates
# Out:
# C:\Users\aswin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='revives', ylabel='Density'>

# %%
pubg_corr = pubg.corr()
plt.subplots(figsize = (12,9))
sns.heatmap(pubg_corr,square=True)
#winpoints and killpoints are highly correlated
#walkdistance and boosts are highly correlated
#damagedealt and kills are highly correlated
# Out:
# <AxesSubplot:>
