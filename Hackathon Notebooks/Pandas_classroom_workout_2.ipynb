# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'a': [1, np.nan, np.nan], 'b': [np.nan, 2,3], 'c':[4,5,6]})

# %%
df
# Out:
#      a    b  c
# 0  1.0  NaN  4
# 1  NaN  2.0  5
# 2  NaN  3.0  6

# %%
df['b'].fillna(df['b'].mean())
# Out:
# 0    2.5
# 1    2.0
# 2    3.0
# Name: b, dtype: float64

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
pd.concat([df1,df2,df3], axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.get_dummies(df1['A'])
# Out:
#    A0  A1  A2  A3
# 0   1   0   0   0
# 1   0   1   0   0
# 2   0   0   1   0
# 3   0   0   0   1

# %%
d1 = {'year':[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],'car_type': ['toy', 'toy', 'hyun', 'toy', 'hyun', 'vw', 'vw', 'vw'],
     'sales':[100,200,150,124,545, 897, 345,500]}

# %%
cars = pd.DataFrame(d1)

# %%
cars
# Out:
#    year car_type  sales
# 0  2010      toy    100
# 1  2011      toy    200
# 2  2012     hyun    150
# 3  2013      toy    124
# 4  2014     hyun    545
# 5  2015       vw    897
# 6  2016       vw    345
# 7  2017       vw    500

# %%
cars_encoded = pd.get_dummies(cars['car_type'])

# %%
cars_encoded
# Out:
#    hyun  toy  vw
# 0     0    1   0
# 1     0    1   0
# 2     1    0   0
# 3     0    1   0
# 4     1    0   0
# 5     0    0   1
# 6     0    0   1
# 7     0    0   1

# %%
pd.concat([cars, cars_encoded], axis=1)
# Out:
#    year car_type  sales  hyun  toy  vw
# 0  2010      toy    100     0    1   0
# 1  2011      toy    200     0    1   0
# 2  2012     hyun    150     1    0   0
# 3  2013      toy    124     0    1   0
# 4  2014     hyun    545     1    0   0
# 5  2015       vw    897     0    0   1
# 6  2016       vw    345     0    0   1
# 7  2017       vw    500     0    0   1

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left, right, how='inner', on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
merged_df = pd.merge(left, right, how='outer', on=['key1', 'key2'])

# %%
merged_df
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df.sort_values(['col2', 'col3'])
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.loc[4] = [5, 444, 'pqd']

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz
# 4     5   444  pqd

# %%
df.sort_values(['col2', 'col3'])
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 4     5   444  pqd
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.sort_values('col1')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.sort_values('col1', ascending=False)
# Out:
#    col1  col2 col3
# 3     4   444  xyz
# 2     3   666  ghi
# 1     2   555  def
# 0     1   444  abc

# %%
df.tail(10)
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz
# 4     5   444  pqd

# %%
df['col2'].value_counts()
# Out:
# 444    3
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
d1 = {'year':[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],'car_type': ['toy', 'toy', 'hyun', 'toy', 'hyun', 'vw', 'vw', 'vw'],
     'sales':[100,200,150,124,545, 897, 345,500]}

# %%
cars = pd.DataFrame(d1)

# %%
cars
# Out:
#    year car_type  sales
# 0  2010      toy    100
# 1  2011      toy    200
# 2  2012     hyun    150
# 3  2013      toy    124
# 4  2014     hyun    545
# 5  2015       vw    897
# 6  2016       vw    345
# 7  2017       vw    500

# %%
cars['car_type'].value_counts()
# Out:
# vw      3
# toy     3
# hyun    2
# Name: car_type, dtype: int64

# %%
df = pd.read_csv('C:\\DS Study Materials\\Datasets\\USA_Housing.csv')

# %%
df.tail(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4990      52723.876555             5.452237                   8.124571
# 4991      74102.191890             5.657841                   7.683993
# 4992      87499.125743             6.403473                   4.836091
# 4993      69639.140896             5.007510                   7.778375
# 4994      73060.846226             5.293682                   6.312253
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4990                          6.39     14802.088438  4.795006e+05
# ...

# %%
outside = ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']
inside = [1,2,3,1,2,3]

# %%
hier_index = list(zip(outside,inside))

# %%
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
df = pd.DataFrame(np.random.randn(6,2), hier_index, columns= ['A', 'B'])

# %%
df
# Out:
#              A         B
# G1 1  1.243257  1.331130
#    2  0.596766  0.178745
#    3 -1.003149 -1.247090
# G2 1 -0.100184  2.065202
#    2  1.545449 -1.560029
#    3  0.183418 -0.953401

# %%
df.loc['G1'].loc[1]['B']
# Out:
# 1.3311299149675135

# %%
df.loc['G1'].loc[1,'B']
# Out:
# 1.3311299149675135

# %%
df
# Out:
#              A         B
# G1 1  1.243257  1.331130
#    2  0.596766  0.178745
#    3 -1.003149 -1.247090
# G2 1 -0.100184  2.065202
#    2  1.545449 -1.560029
#    3  0.183418 -0.953401

# %%
df.index.names = ['Group', 'Num']

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1    1.243257  1.331130
#       2    0.596766  0.178745
#       3   -1.003149 -1.247090
# G2    1   -0.100184  2.065202
#       2    1.545449 -1.560029
#       3    0.183418 -0.953401

# %%
df.xs(1, level=1)
# Out:
#               A         B
# Group
# G1     1.243257  1.331130
# G2    -0.100184  2.065202
